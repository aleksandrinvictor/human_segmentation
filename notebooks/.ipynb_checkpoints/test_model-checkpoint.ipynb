# %%
import os
os.chdir("..")

# %%
from hydra.experimental import compose, initialize
from hydra.utils import instantiate
from omegaconf import OmegaConf
from humseg.models import Unet
import matplotlib.pyplot as plt
import cv2
import numpy as np
import torch.nn as nn
import torch
from humseg.dataset import HumsegDataModule

# %%
with initialize(config_path="./../conf", job_name="test_app"):
    cfg = compose(config_name="config")

# %%
model = instantiate(cfg.lit_module, cfg=cfg)

# %%
datamodule = instantiate(cfg.datamodule, cfg=cfg)

# %%
datamodule.setup(stage="fit")

# %%
len(datamodule.train_dataset)
# Out:
# 1315

# %%
len(datamodule.valid_dataset)
# Out:
# 145

# %%
val_images, val_masks = next(iter(datamodule.val_dataloader()))

# %%
len(val_masks)
# Out:
# 24

# %%
len(val_images)
# Out:
# 24

# %%
train_images, train_masks = next(iter(datamodule.train_dataloader()))

# %%
model = model.model

# %%
model
# Out:
# Unet(
#   (encoder_layers): ModuleList(
#     (0): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (1): Sequential(
#         (0): BasicBlock(
#           (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): BasicBlock(
# ...

# %%
train_images[0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
train_images.shape
# Out:
# torch.Size([24, 3, 224, 224])

# %%
output = model(train_images.float())

# %%
output.shape
# Out:
# torch.Size([24, 1, 224, 224])

# %%
plt.imshow(train_images[0].permute([1, 2, 0]).detach().numpy())

# %%
pred_mask = (torch.sigmoid(output[0]) > 0.5).type(output[0].dtype)

# %%
pred_mask.shape
# Out:
# torch.Size([1, 224, 224])

# %%
plt.imshow(pred_mask.detach().numpy().squeeze())
